# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Qzilla1/Fly-Rank-Week-1/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## Errors and interpretation:The model performs better on common patterns in the data and makes larger errors on unusual or low-frequency examples.Feature importance indicates that only a small number of features contribute most of the predictive signal, while others have relatively little impact.These findings are observed and directional. They should be used for decision support rather than treated as proof of causation.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Split design:I used the same train/test split as my Week-4 baseline so the comparison is fair.Using the same split ensures that differences in performance are due to the model rather than different evaluation data. No information from the test set is used during training, helping avoid data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Train + compare vs my baseline:The model was trained using the same training data and evaluated on the same test data as the Week-4 baseline.The comparison uses the same evaluation metric so that performance differences are directly comparable.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Errors and interpretation:The model performs better on common patterns in the data and makes larger errors on unusual or low-frequency examples.Feature importance indicates that only a small number of features contribute most of the predictive signal, while others have relatively little impact.These findings are observed and directional. They should be used for decision support rather than treated as proof of causation.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
